# %% [markdown]
# <a href="https://colab.research.google.com/github/ASHISH-0415/algo-lab-evensem2026/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )
import random
import time
import matplotlib.pyplot as plt

def even_odd_first(numbers):
    if not numbers:
        return None
    if numbers[0] % 2 == 0:
        return "Even"
    else:
        return "Odd"

sizes = [100, 500, 1000, 5000, 10000, 20000]
times = []

for n in sizes:
    arr = [random.randint(0, 100000) for _ in range(n)]
    start = time.time()
    even_odd_first(arr)
    end = time.time()
    times.append(end - start)
    print(f"n={n}, time={end - start:.10f} seconds")

plt.plot(sizes, times, marker='o')
plt.xlabel("Number of elements (n)")
plt.ylabel("Time taken (seconds)")
plt.title("Constant Time Function Performance (O(1))")
plt.grid(True)
plt.show()
# Out:
# n=100, time=0.0000028610 seconds
# n=500, time=0.0000026226 seconds
# n=1000, time=0.0000026226 seconds
# n=5000, time=0.0000042915 seconds
# n=10000, time=0.0000059605 seconds
# n=20000, time=0.0000061989 seconds

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)

import random
import time
import matplotlib.pyplot as plt

def count_positive(numbers):
    count = 0
    for num in numbers:
        if num > 0:
            count += 1
    return count

sizes = [100, 500, 1000, 5000, 10000, 20000]
times = []

for n in sizes:
    arr = [random.randint(-100000, 100000) for _ in range(n)]
    start = time.time()
    count_positive(arr)
    end = time.time()
    times.append(end - start)
    print(f"n={n}, time={end - start:.6f} seconds")

plt.plot(sizes, times, marker='o')
plt.xlabel("Number of elements (n)")
plt.ylabel("Time taken (seconds)")
plt.title("Linear Time Function Performance (O(n))")
plt.grid(True)
plt.show()
# Out:
# n=100, time=0.000011 seconds
# n=500, time=0.000027 seconds
# n=1000, time=0.000059 seconds
# n=5000, time=0.000288 seconds
# n=10000, time=0.000675 seconds
# n=20000, time=0.001255 seconds

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.
import random
import time
import matplotlib.pyplot as plt

def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

sizes = [100, 500, 1000, 5000, 10000, 20000, 50000]
times = []

for n in sizes:
    arr = sorted([random.randint(0, 1000000) for _ in range(n)])
    target = random.choice(arr)
    start = time.time()
    binary_search(arr, target)
    end = time.time()
    times.append(end - start)
    print(f"n={n}, time={end - start:.10f} seconds")

plt.plot(sizes, times, marker='o')
plt.xlabel("Number of elements (n)")
plt.ylabel("Time taken (seconds)")
plt.title("Binary Search Performance (O(log n))")
plt.grid(True)
plt.show()
# Out:
# n=100, time=0.0000061989 seconds
# n=500, time=0.0000052452 seconds
# n=1000, time=0.0000040531 seconds
# n=5000, time=0.0000064373 seconds
# n=10000, time=0.0000088215 seconds
# n=20000, time=0.0000104904 seconds
# n=50000, time=0.0000109673 seconds

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.
import random
import time
import matplotlib.pyplot as plt

def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0

        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
    return arr

sizes = [100, 500, 1000, 5000, 10000, 20000, 50000]
times = []

for n in sizes:
    arr = [random.randint(0, 1000000) for _ in range(n)]
    start = time.time()
    merge_sort(arr)
    end = time.time()
    times.append(end - start)
    print(f"n={n}, time={end - start:.6f} seconds")

plt.plot(sizes, times, marker='o')
plt.xlabel("Number of elements (n)")
plt.ylabel("Time taken (seconds)")
plt.title("Log-Linear Time Performance (O(n log n)) - Merge Sort")
plt.grid(True)
plt.show()
# Out:
# n=100, time=0.000142 seconds
# n=500, time=0.001356 seconds
# n=1000, time=0.002553 seconds
# n=5000, time=0.011144 seconds
# n=10000, time=0.026372 seconds
# n=20000, time=0.053816 seconds
# n=50000, time=0.174487 seconds

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as wel similar to above example
import random
import time
import matplotlib.pyplot as plt

def matrix_multiply(A, B, n):
    result = [[0 for _ in range(n)] for _ in range(n)]
    for i in range(n):
        for j in range(n):
            for k in range(n):
                result[i][j] += A[i][k] * B[k][j]
    return result

sizes = [10, 20, 30, 40, 50]  # keep small due to O(n^3)
times = []

for n in sizes:
    A = [[random.randint(0, 100) for _ in range(n)] for _ in range(n)]
    B = [[random.randint(0, 100) for _ in range(n)] for _ in range(n)]
    start = time.time()
    matrix_multiply(A, B, n)
    end = time.time()
    times.append(end - start)
    print(f"n={n}, time={end - start:.6f} seconds")

plt.plot(sizes, times, marker='o')
plt.xlabel("Matrix size (n x n)")
plt.ylabel("Time taken (seconds)")
plt.title("Polynomial Time Performance (O(n^3)) - Matrix Multiplication")
plt.grid(True)
plt.show()
# Out:
# n=10, time=0.000136 seconds
# n=20, time=0.000960 seconds
# n=30, time=0.003151 seconds
# n=40, time=0.007131 seconds
# n=50, time=0.013803 seconds

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
import time
import matplotlib.pyplot as plt

def fibonacci_recursive(n):
    if n <= 1:
        return n
    return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)

sizes = [5, 10, 20, 25, 30]  # keep small due to exponential growth
times = []

for n in sizes:
    start = time.time()
    fibonacci_recursive(n)
    end = time.time()
    times.append(end - start)
    print(f"n={n}, time={end - start:.6f} seconds")

plt.plot(sizes, times, marker='o')
plt.xlabel("Input size (n)")
plt.ylabel("Time taken (seconds)")
plt.title("Exponential Time Performance (O(2^n)) - Recursive Fibonacci")
plt.grid(True)
plt.show()
# Out:
# n=5, time=0.000004 seconds
# n=10, time=0.000017 seconds
# n=20, time=0.001690 seconds
# n=25, time=0.014705 seconds
# n=30, time=0.162107 seconds

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
import matplotlib.pyplot as plt
import numpy as np

n_values = np.arange(1, 10, 1)

f_linear = n_values
f_log = np.log2(n_values)
f_quadratic = n_values**2
f_exponential = 2**n_values

plt.plot(n_values, f_linear, 'b-', label='O(n) Linear')
plt.plot(n_values, f_log, 'r-', label='O(log n) Logarithmic')
plt.plot(n_values, f_quadratic, 'g-', label='O(n^2) Quadratic')
plt.plot(n_values, f_exponential, 'y-', label='O(2^n) Exponential')

plt.xlabel("Values of n")
plt.ylabel("Time Complexity")
plt.title("Comparison of Time Complexities")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(log n)
import random
import time
import matplotlib.pyplot as plt

def quicksort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[len(arr) // 2]
        left = [x for x in arr if x < pivot]
        middle = [x for x in arr if x == pivot]
        right = [x for x in arr if x > pivot]
        return quicksort(left) + middle + quicksort(right)

sizes = [100, 500, 1000, 5000, 10000, 20000]
times = []

for n in sizes:
    arr = [random.randint(0, 100000) for _ in range(n)]
    start = time.time()
    quicksort(arr)
    end = time.time()
    times.append(end - start)
    print(f"n={n}, time={end - start:.6f} seconds")

plt.plot(sizes, times, marker='o')
plt.xlabel("Number of elements (n)")
plt.ylabel("Time taken (seconds)")
plt.title("Quicksort Performance (O(n log n))")
plt.grid(True)
plt.show()
# Out:
# n=100, time=0.000128 seconds
# n=500, time=0.000664 seconds
# n=1000, time=0.001988 seconds
# n=5000, time=0.008633 seconds
# n=10000, time=0.030197 seconds
# n=20000, time=0.039552 seconds
